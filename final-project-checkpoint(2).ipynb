# %% [markdown]
# import sklearn and necessary libraries

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor  
import numpy as np
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
# %matplotlib inline

# %% [markdown]
# Load in our datasets, no label for the TEST

# %%
XTRAIN = np.loadtxt("X_train",delimiter=",")
XTEST = np.loadtxt("X_test",delimiter=",")
y_train = np.loadtxt("y_train",delimiter=",")

# %%
print(XTRAIN.shape)
print(y_train.shape)
print(XTEST.shape)
#shift X over
# Out:
# (27930, 9491)
# (27930,)
# (9311, 9491)

# %% [markdown]
# Now, because we were not given labels for the test set, we are splitting the Training set 80-20. 20% allocated for testing after fitting it with the first 80%

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     XTRAIN, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Splice NP array in order to have a smaller dataset for easier testing (I dont have to wait all day for it to fit)

# %%
shiftedxtrain = X_train[0:2000,:]
shiftedytrain = y_train[0:2000]
print(shiftedxtrain.shape)
print(shiftedytrain.shape)
# Out:
# (2000, 9491)
# (2000,)

# %% [markdown]
# For this project we are going to use a few different models and decide on the best regression technique based on z-scores produced by each fitting

# %%
regressorDecTree = DecisionTreeRegressor(random_state = 0)  
regressorDecTree.fit(X_train, y_train) 
predictionsDecTree = regressor.predict(X_test)

# %% [markdown]
# Plot y_test vs predictions done on our "test set" for Decision tree regression

# %%
plt.scatter(y_test, predictionsDecTree)
plt.xlabel("True Values")
plt.ylabel("Predictions Decision Tree")
plt.show()
print(regressorDecTree.score(X_test, y_test))
# Out:
# 0.2911601458199856
